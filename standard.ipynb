# %% [markdown]
# <a href="https://colab.research.google.com/github/sho20204114/20204114/blob/master/standard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip list | grep numpy
# !pip check
# !conda install numpy==1.19.3
# !python3 -m pip install spleeter
# Out:
# numpy                         1.21.6
# nbclient 0.6.4 has requirement jupyter-client>=6.1.5, but you have jupyter-client 5.3.5.
# nbclient 0.6.4 has requirement traitlets>=5.2.2, but you have traitlets 5.1.1.
# datascience 0.10.6 has requirement folium==0.2.1, but you have folium 0.8.3.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9.
# /bin/bash: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 51 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 183 kB 11.4 MB/s
# ...
#      |████████████████████████████████| 454.3 MB 16 kB/s
# ...
#      |████████████████████████████████| 25.3 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 77 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 14.8 MB 57.5 MB/s
# ...
#      |████████████████████████████████| 132 kB 73.2 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 51.8 MB/s
# ...

# %%
# !spleeter separate -o . '/content/drive/MyDrive/Colab_Notebooks/music/koiuta.mp3'
# !spleeter separate -o . '/content/drive/MyDrive/Colab_Notebooks/music/love so sweet.mp3'
# !spleeter separate -o . '/content/drive/MyDrive/Colab_Notebooks/music/shinderaboy.mp3'
# !spleeter separate -o . '/content/drive/MyDrive/Colab_Notebooks/music/yoasobi.mp3'
# Out:
# INFO:spleeter:File ./koiuta/vocals.wav written succesfully
# INFO:spleeter:File ./koiuta/accompaniment.wav written succesfully
# tcmalloc: large alloc 1310801920 bytes == 0xc8c78000 @  0x7f92ed4731e7 0x7f92b6b25f42 0x7f92b952ac5a 0x7f92b98cb5c4 0x7f92b991bb1f 0x7f92b991d769 0x7f92b991e757 0x7f92b991fe6e 0x7f92b9924942 0x7f92b9924e3f 0x7f92af7c4e54 0x7f92af7b91be 0x7f92b4c6f021 0x7f92b4c6bd33 0x7f92aff018b5 0x7f92ece376db 0x7f92ed17061f
# tcmalloc: large alloc 1310801920 bytes == 0x11d28c000 @  0x7f92ed4731e7 0x7f92b6b25f42 0x7f92b952ac5a 0x7f92b98cb5c4 0x7f92b991bb1f 0x7f92b991d769 0x7f92b991e757 0x7f92b991fe6e 0x7f92b9924942 0x7f92b9924e3f 0x7f92af7c4e54 0x7f92af7b91be 0x7f92b4c6f021 0x7f92b4c6bd33 0x7f92aff018b5 0x7f92ece376db 0x7f92ed17061f
# INFO:spleeter:File ./love so sweet/vocals.wav written succesfully
# INFO:spleeter:File ./love so sweet/accompaniment.wav written succesfully
# INFO:spleeter:File ./shinderaboy/vocals.wav written succesfully
# ...
